# %% [markdown]
# <a href="https://colab.research.google.com/github/Saranya-raj-1229/Car-price-prediction/blob/main/Car_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data=pd.read_csv('car_price_prediction_.csv')
data
# Out:
#       Car ID   Brand  Year  Engine Size Fuel Type Transmission  Mileage  \
# 0          1   Tesla  2016          2.3    Petrol       Manual   114832
# 1          2     BMW  2018          4.4  Electric       Manual   143190
# 2          3    Audi  2013          4.5  Electric       Manual   181601
# 3          4   Tesla  2011          4.1    Diesel    Automatic    68682
# 4          5    Ford  2009          2.6    Diesel       Manual   223009
# ...      ...     ...   ...          ...       ...          ...      ...
# 2495    2496    Audi  2020          2.4    Petrol    Automatic    22650
# 2496    2497    Audi  2001          5.7    Hybrid       Manual    77701
# 2497    2498    Ford  2021          1.1    Hybrid       Manual   272827
# 2498    2499    Audi  2002          4.5    Diesel       Manual   229164
# 2499    2500  Toyota  2005          4.6    Diesel    Automatic    80978
#
#      Condition     Price     Model
# 0          New  26613.92   Model X
# 1         Used  14679.61  5 Series
# 2          New  44402.61        A4
# 3          New  86374.33   Model Y
# 4     Like New  73577.10   Mustang
# ...        ...       ...       ...
# 2495  Like New  61384.10        Q5
# 2496  Like New  24710.35        A3
# 2497  Like New  29902.45    Fiesta
# 2498  Like New  46085.67        Q5
# 2499      Used  16594.14      RAV4
#
# [2500 rows x 10 columns]

# %% [markdown]
# # **FEATURES :**
# 1. Car ID - Unique number given for all cars
# 2. Brand - Brand name of each cars
# 3. Year - Shows the year of manufacturing
# 4. Engine size - Shows the cubic capacity of the car
# 5. Fuel Type - Shows the type of fuel source
# 6. Transmission - Shows the type of gearbox wheather Automatic or Manaul
# 7. Mileage - Shows the mileage of the cars
# 8. Condition - Tells the condition of each cars
# 9. Price - Shows the price for each cars
# 10. Model - Shows the model of each cars

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car ID        2500 non-null   int64
#  1   Brand         2500 non-null   object
#  2   Year          2500 non-null   int64
#  3   Engine Size   2500 non-null   float64
#  4   Fuel Type     2500 non-null   object
#  5   Transmission  2500 non-null   object
#  6   Mileage       2500 non-null   int64
#  7   Condition     2500 non-null   object
#  8   Price         2500 non-null   float64
#  9   Model         2500 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 195.4+ KB

# %% [markdown]
# # **EDA :**
# 1. What is the distribution of the target variable (Price)?
# 📊 Plot: Histogram + KDE
# 2. How many cars are listed per brand?
# 📊 Plot: Bar chart
# 3. What is the average price for each brand?
# 📊 Plot: Bar chart (sorted by price)
# 4. Which car models appear most frequently?
# 📊 Plot: Horizontal bar chart
# 5. How does price vary with car manufacturing year?
# 📊 Plot: Line plot or scatter plot
# 6. How many cars are petrol, diesel, CNG, electric?
# 📊 Plot: Pie chart or bar chart
# 7. What is the average price for each fuel type?
# 📊 Plot: Bar chart
# 8. Does transmission type (Manual/Automatic) affect price?
# 📊 Plot: Boxplot
# 9. How does mileage affect car price?
# 📊 Plot: Scatter plot with regression line
# 10. Does engine size affect price?
# 📊 Plot: Scatter plot
# 11. Do newer cars have higher mileage?
# 📊 Plot: Scatter plot
# 12. How many owners do most cars have?
# 📊 Plot: Countplot (bar chart)
# 13. What is the condition distribution (excellent/good/average)?
# 📊 Plot: Pie or bar chart
# 14. What is price variation across condition levels?
# 📊 Plot: Boxplot
# 15. What features correlate most with price?
# 📊 Plot: Correlation heatmap
# 16. Which numerical variable has the highest variance?
# 📊 Plot: Variance bar chart
# 17. Are there outliers in price, mileage, engine size?
# 📊 Plot: Boxplot for each numerical feature
# 18. How does price differ by brand + fuel type combination?
# 📊 Plot: Grouped bar chart
# 19. Are certain brands more fuel-efficient?
# 📊 Plot: Boxplot of mileage by brand
# 20. How are engine size and mileage related?
# 📊 Plot: Scatter plot
# 21. Which features have strong pairwise relationships?
# 📊 Plot: Pairplot (if allowed), or multiple scatter plots
# 22. What is the distribution of car ages in the dataset?
# 📊 Plot: Histogram
# 23. How many cars fall into price ranges (bins)?
# 📊 Plot: Histogram with bins (e.g., 0–2L, 2–5L, 5–10L)
# 24. Cluster cars based on engine size, mileage, price—are there groups?
# 📊 Plot: Scatter plot with clusters (K-means)
# 25. Which features are most important in predicting price?
# 📊 Plot: Feature importance bar chart (after training ML model)

# %%
# 1.What is the distribution of the target variable (Price)? 📊 Plot: Histogram + KDE
sns.histplot(data['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
# 2.How many cars are listed per brand? 📊 Plot: Bar chart
a=data['Brand'].value_counts()
a
# Out:
# Brand
# Toyota      374
# Audi        368
# BMW         358
# Mercedes    353
# Honda       352
# Tesla       348
# Ford        347
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(a.index, a.values)
plt.xlabel("Brand")
plt.ylabel("Number of Cars")
plt.title("Number of Cars Listed per Brand")
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %%
# 3.What is the average price for each brand? 📊 Plot: Bar chart (sorted by price)
b=data.groupby('Brand')['Price'].mean()
b
# Out:
# Brand
# Audi        51953.424810
# BMW         54157.114385
# Ford        51593.254813
# Honda       52050.283949
# Mercedes    53191.090085
# Tesla       53475.547471
# Toyota      52078.728235
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=b.index, y=b.values)
plt.xticks(rotation=90)
plt.title("Average Price by Brand")
plt.xlabel("Brand")
plt.ylabel("Average Price")
plt.grid(axis='y')
plt.show()

# %%
# 4.Which car models appear most frequently? 📊 Plot: Horizontal bar chart
c=data['Model'].value_counts().head(20)
c
# Out:
# Model
# Fiesta      103
# Corolla     103
# A3           98
# A4           96
# Q7           95
# CR-V         95
# 5 Series     93
# 3 Series     93
# Prius        93
# Model X      93
# C-Class      92
# X3           92
# GLA          92
# Camry        90
# E-Class      89
# Fit          89
# Model Y      89
# RAV4         88
# Accord       88
# Model 3      87
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.barh(c.index, c.values)
plt.title("Top 20 Most Frequent Car Models")
plt.xlabel("Count")
plt.ylabel("Model")
plt.grid(axis='x')
plt.show()

# %%
# 5.How does price vary with car manufacturing year? 📊 Plot: Line plot or scatter plot
d=data.groupby('Year')['Price'].mean()
d
# Out:
# Year
# 2000    53094.163441
# 2001    48944.057706
# 2002    57197.476000
# 2003    52260.187373
# 2004    51517.976900
# 2005    57534.323592
# 2006    53437.595930
# 2007    56464.203545
# 2008    53104.788716
# 2009    52932.735778
# 2010    53650.244632
# 2011    51414.871188
# 2012    57092.138378
# 2013    52495.034737
# 2014    54202.577248
# 2015    51516.460909
# 2016    51977.464068
# 2017    49045.689175
# 2018    52640.946604
# 2019    49848.339029
# 2020    48281.739426
# 2021    48819.715089
# 2022    54656.139554
# 2023    51328.692718
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(8, 5))
plt.plot(d.index,d.values)
plt.title("Average Price by Manufacturing Year")
plt.xlabel("Year")
plt.ylabel("Average Price")
plt.tight_layout()
plt.show()

# %%
# 6.How many cars are petrol, diesel, CNG, electric? 📊 Plot: Pie chart or bar chart
e=data['Fuel Type'].value_counts()
e
# Out:
# Fuel Type
# Diesel      655
# Petrol      630
# Electric    614
# Hybrid      601
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(e.values, labels=e.index, autopct='%1.1f%%')
plt.title("Fuel Type Distribution")
plt.show()

# %%
# 7.What is the average price for each fuel type? 📊 Plot: Bar chart
f=data.groupby('Fuel Type')['Price'].mean()
f
# Out:
# Fuel Type
# Diesel      54996.997588
# Electric    51103.013534
# Hybrid      52547.394759
# Petrol      51767.918016
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=f.index, y=f.values)
plt.title("Average Price by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Average Price")
plt.show()

# %%
# 8.Does transmission type (Manual/Automatic) affect price? 📊 Plot: Boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x='Transmission', y='Price', data=data)
plt.title("Price Distribution by Transmission Type")
plt.xlabel("Transmission")
plt.ylabel("Price")
plt.show()

# %%
# 10.Does engine size affect price? 📊 Plot: Scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Engine Size', y='Price', data=data, alpha=0.7)
plt.title("Price vs Engine Size")
plt.xlabel("Engine (CC)")
plt.ylabel("Price")
plt.show()

# %%
# 11.Do newer cars have higher mileage? 📊 Plot: Scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Year', y='Mileage', data=data, alpha=0.7)
plt.title("Mileage vs Manufacturing Year")
plt.xlabel("Year")
plt.ylabel("Mileage")
plt.show()

# %%
# 13.What is the condition distribution (excellent/good/average)? 📊 Plot: Pie or bar chart
g=data['Condition'].value_counts()
g
# Out:
# Condition
# Used        855
# Like New    836
# New         809
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(g.values, labels=g.index, autopct='%1.1f%%')
plt.title("Car Condition Distribution")
plt.show()

# %%
# 14.What is price variation across condition levels? 📊 Plot: Boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x='Condition', y='Price', data=data, order=data['Condition'].value_counts().index)
plt.title("Price Distribution by Condition")
plt.xlabel("Condition")
plt.ylabel("Price")
plt.show()

# %%
# 18.How does price differ by brand + fuel type combination? 📊 Plot: Grouped bar chart
h=data.groupby(['Brand', 'Fuel Type'])['Price'].mean()
h
# Out:
# Brand     Fuel Type
# Audi      Diesel       56574.073814
#           Electric     51376.561170
#           Hybrid       50374.120000
#           Petrol       49182.028125
# BMW       Diesel       59334.373587
#           Electric     50654.630879
#           Hybrid       55599.859302
#           Petrol       50992.418764
# Ford      Diesel       52679.123294
#           Electric     47298.914706
#           Hybrid       52169.371628
#           Petrol       54045.716813
# Honda     Diesel       50711.301262
#           Electric     50602.706667
#           Hybrid       55014.680805
#           Petrol       51919.030920
# Mercedes  Diesel       54449.243494
#           Electric     54237.306707
#           Hybrid       50099.797125
#           Petrol       53719.672870
# Tesla     Diesel       56368.296818
#           Electric     53285.740600
#           Hybrid       51733.169529
#           Petrol       52309.159067
# Toyota    Diesel       55101.860280
#           Electric     49961.358506
#           Hybrid       52509.856875
#           Petrol       49928.105476
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Brand', y='Price', hue='Fuel Type', data=data)
plt.title("Average Price by Brand and Fuel Type")
plt.xlabel("Brand")
plt.ylabel("Average Price")
plt.show()

# %%
# 19.Are certain brands more fuel-efficient? 📊 Plot: Boxplot of mileage by brand
sns.boxplot(x='Brand', y='Mileage', data=data)
plt.title("Mileage Distribution by Brand (Top 10)")
plt.xlabel("Brand")
plt.ylabel("Mileage")
plt.xticks(rotation=45)
plt.show()

# %%
# 20.How are engine size and mileage related? 📊 Plot: Scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Engine Size', y='Mileage', data=data, alpha=0.7)
plt.title("Engine Size vs Mileage")
plt.xlabel("Engine (CC)")
plt.ylabel("Mileage")
plt.show()

# %%
# 22.What is the distribution of car ages in the dataset? 📊 Plot: Histogram
CURRENT_YEAR = 2025
data['Age']=CURRENT_YEAR - data['Year']

plt.figure(figsize=(8, 5))
sns.histplot(data['Age'], kde=True, bins=20)
plt.title("Distribution of Car Ages")
plt.xlabel("Age (years)")
plt.ylabel("Count")
plt.show()
